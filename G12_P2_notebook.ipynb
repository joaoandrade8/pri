# %% [markdown]
# <H3>PRI 2023/24: second
#     project delivery</H3>

# %% [markdown]
# **GROUP X**
# - João Andrade, 98950
# - Inês Alves, ist99084

# %% [markdown]
# <H2>Main facilities</H2>

# %% [markdown]
# <h3>Part I: clustering</h3>

# %% [markdown]
# *A) Clustering*

# %%
import proj2
import numpy as np
import matplotlib.pyplot as plt

c, cluster_range, scores, min, max = proj2.sentence_clustering("413.txt")

# Plot silhouette scores
plt.figure(figsize=(10, 6))
plt.plot(cluster_range, scores, marker='o', linestyle='-')
plt.title('Silhouette Score for Different Numbers of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.xticks(np.arange(min, max + 1, step=1))
plt.grid(True)
plt.show()
# Out:
# {'sainsbury', 'was', 'to', 'the', 'and', 'party', 'labour'}

# %% [markdown]
# *B) Summarization*

# %%
import proj2
import numpy as np

c, r, scores, min_cluster, max_cluster = proj2.sentence_clustering("001.txt")
s= proj2.summarization("001.txt", c)


# Plot cluster distribution
plt.figure(figsize=(8, 6))
sentences, cluster_counts = np.unique(c, return_counts=True)  # Count the number of sentences in each cluster
plt.bar(sentences, cluster_counts)
plt.xlabel('Cluster')
plt.ylabel('Number of Sentences')
plt.title('Distribution of Sentences across Clusters')
plt.xticks(sentences)  # Set x-axis tick locations to cluster numbers
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import proj2
#       2 import numpy as np
#       4 c, r, scores, min_cluster, max_cluster = proj2.sentence_clustering("001.txt")
#
# File ~/Library/CloudStorage/OneDrive-UniversidadedeLisboa/mestrado/1ano/p3/pri/pri/proj2.py:1
# ----> 1 import sklearn
#       2 from sklearn.feature_extraction.text import TfidfVectorizer
#       3 from sklearn.cluster import AgglomerativeClustering
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# *C) Keyword extraction*

# %%
extracted_keywords = keyword_extraction("001.txt", c)

# Convert the extracted keywords to lowercase for consistency
extracted_keywords_lower = [keyword.lower() for keyword in extracted_keywords]

# Frequency Distribution
keyword_freq = nltk.FreqDist(extracted_keywords_lower)
print("Frequency Distribution of Extracted Keywords:")
for keyword, freq in keyword_freq.items():
    print(f"{keyword}: {freq}")

# Bar Chart
plt.figure(figsize=(10, 6))
plt.bar(keyword_freq.keys(), keyword_freq.values())
plt.xlabel('Keywords')
plt.ylabel('Frequency')
plt.title('Keyword Frequency Distribution')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Summary Statistics
total_keywords = len(extracted_keywords)
average_frequency = np.mean(list(keyword_freq.values()))
print(f"\nTotal Unique Keywords Extracted: {total_keywords}")
print(f"Average Frequency of Keywords: {average_frequency}")

# %% [markdown]
# *D) Evaluation*

# %%
#code, statistics and/or charts here

# %% [markdown]
# <h3>Part II: classification</h3>

# %% [markdown]
# *A) Feature extraction*

# %%
#code and statistics here

# %% [markdown]
# *B) Classification*

# %%
#code here

# %% [markdown]
# *C) Ranking extension*

# %%
#code here

# %% [markdown]
# *D) Evaluation*

# %%
#code, statistics and/or charts here

# %% [markdown]
# <H2>Question materials (optional)</H2>

# %% [markdown]
# <H3>Part I: clustering</H3>

# %% [markdown]
# **(1)** Do clustering-guided summarization alters the behavior and efficacy of the IR system?

# %%
#code, statistics and/or charts here

# %% [markdown]
# **(2)** How sentence representations, clustering choices, and rank criteria impact summarization?

# %%
#code, statistics and/or charts here

# %% [markdown]
# **...** (additional questions with empirical results)

# %% [markdown]
# <H3>END</H3>
